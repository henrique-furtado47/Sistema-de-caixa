# %% [markdown]
# <a href="https://colab.research.google.com/github/henrique-furtado47/Sistema-de-caixa/blob/main/Sistema_de_caixa_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
estoque= {"nomes": [], "quantidade": [], "preco": [], "codigo": []}
carrinho= {"nomes": [], "quantidade": [], "preco": [], "codigo": []}

# %%
def visualizar_estoque():
  df=pd.DataFrame(estoque)
  display(df)

# %%
def visualizar_carrinho():
  df=pd.DataFrame(carrinho)
  display(df)

# %%
def cadastrar_produto():
    nome= input("Digite o nome do produto: ")
    quantidade= int(input("Digite a quantidade do produto: "))
    preco= float(input("Digite o preço do produto: "))
    for i in range(len(estoque)):
        codigo= len(estoque["codigo"])+1
    estoque["nomes"].append(nome)
    estoque["quantidade"].append(quantidade)
    estoque["preco"].append(preco)
    estoque["codigo"].append(codigo)
    print("Produto cadastrado com sucesso!")

# %%
def adicionar_carrinho():
    codigo= int(input("Digite o código do produto: "))
    if codigo in estoque["codigo"]:
        index=estoque["codigo"].index(codigo)
        carrinho["nomes"].append(estoque["nomes"][index])
        carrinho["quantidade"].append(input("Digite a quantidade do produto: "))
        if int(carrinho["quantidade"][-1])>estoque["quantidade"][index]:
            print("Quantidade insuficiente!")
            carrinho["quantidade"].pop()
            return
        carrinho["preco"].append(estoque["preco"][index])
        carrinho["codigo"].append(estoque["codigo"][index])
        print("Produto adicionado ao carrinho com sucesso!")
    else:
        print("Produto não encontrado!")

# %%
def finalizar_compra():
    total=0
    for i in range(len(carrinho["nomes"])):
      total+= carrinho["preco"][i]*carrinho["quantidade"][i]
    print("Total da compra: ", total)
    estoque["quantidade"][i]-= int(carrinho["quantidade"][i])
    estoque["nome"].pop(i)
    estoque["quantidade"].pop(i)
    estoque["preco"].pop(i)
    estoque["codigo"].pop(i)
    carrinho["nomes"].clear()
    carrinho["quantidade"].clear()
    carrinho["preco"].clear()
    carrinho["codigo"].clear()

# %%
def menu():
    print("1 - Acessar estoque")
    print("2 - Acessar carrinho")
    print("0 - Sair")

# %%
def acessar_estoque():
    print("1 - Cadastrar produto")
    print("2 - Listar produtos")

# %%
def acessar_carrinho():
    print("1 - Adicionar produto ao carrinho")
    print("2 - Listar produtos do carrinho")
    print("3 - Finalizar compra")
    print("0 - Sair")

# %%
while True:
    menu()
    opcao= int(input("Digite uma opção: "))
    if opcao==1:
        acessar_estoque()
        opcao= int(input("Digite uma opção: "))
        if opcao==1:
            cadastrar_produto()
        elif opcao==2:
            visualizar_estoque()
    elif opcao==2:
        acessar_carrinho()
        opcao= int(input("Digite uma opção: "))
        if opcao==1:
            adicionar_carrinho()
        elif opcao==2:
            visualizar_carrinho()
        elif opcao==3:
            finalizar_compra()
    elif opcao==0:
        break
    else:
        print("Opção inválida!")
# Out:
# 1 - Acessar estoque
# 2 - Acessar carrinho
# 0 - Sair
# Digite uma opção: 1
# 1 - Cadastrar produto
# 2 - Listar produtos
# Digite uma opção: 1
# Digite o nome do produto: arroz
# Digite a quantidade do produto: 3
# Digite o preço do produto: 2
# Produto cadastrado com sucesso!
# 1 - Acessar estoque
# 2 - Acessar carrinho
# 0 - Sair
# Digite uma opção: 1
# 1 - Cadastrar produto
# 2 - Listar produtos
# Digite uma opção: 2
#    nomes  quantidade  preco  codigo
# 0  arroz           3    2.0       1
# 1 - Acessar estoque
# 2 - Acessar carrinho
# 0 - Sair
# Digite uma opção: 1
# 1 - Cadastrar produto
# 2 - Listar produtos
# Digite uma opção: 1
# Digite o nome do produto: feijão
# Digite a quantidade do produto: 30
# Digite o preço do produto: 5
# Produto cadastrado com sucesso!
# 1 - Acessar estoque
# 2 - Acessar carrinho
# 0 - Sair
# Digite uma opção: 1
# 1 - Cadastrar produto
# 2 - Listar produtos
# Digite uma opção: 2
#     nomes  quantidade  preco  codigo
# 0   arroz           3    2.0       1
# 1  feijão          30    5.0       2
# 1 - Acessar estoque
# 2 - Acessar carrinho
# 0 - Sair
# Digite uma opção: 2
# 1 - Adicionar produto ao carrinho
# 2 - Listar produtos do carrinho
# 3 - Finalizar compra
# 0 - Sair
# Digite uma opção: 1
# Digite o código do produto: 1
# Digite a quantidade do produto: 2
# Produto adicionado ao carrinho com sucesso!
# 1 - Acessar estoque
# 2 - Acessar carrinho
# 0 - Sair
# Digite uma opção: 2
# 1 - Adicionar produto ao carrinho
# 2 - Listar produtos do carrinho
# 3 - Finalizar compra
# 0 - Sair
# Digite uma opção: 2
#    nomes quantidade  preco  codigo
# 0  arroz          2    2.0       1
# 1 - Acessar estoque
# 2 - Acessar carrinho
# 0 - Sair
# Digite uma opção: 2
# 1 - Adicionar produto ao carrinho
# 2 - Listar produtos do carrinho
# 3 - Finalizar compra
# 0 - Sair
# Digite uma opção: 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-d80a7cce3fed> in <cell line: 1>()
#      17             visualizar_carrinho()
#      18         elif opcao==3:
# ---> 19             finalizar_compra()
#      20     elif opcao==0:
#      21         break
#
# <ipython-input-50-b7277029c891> in finalizar_compra()
#       2     total=0
#       3     for i in range(len(carrinho["nomes"])):
# ----> 4         total+= carrinho["preco"][i]*carrinho["quantidade"][i]
#       5     print("Total da compra: ", total)
#       6     estoque["quantidade"][i]-= int(carrinho["quantidade"][i])
#
# TypeError: can't multiply sequence by non-int of type 'float'
